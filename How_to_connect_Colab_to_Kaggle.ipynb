# %% [markdown]
# Here are the steps to follow in connecting Colab to Kaggle.

# %% [markdown]
# Visit Kaggle.com, register and login

# %% [markdown]
# ![Kaggle homepage.PNG](data:image/png;base64,...)

# %% [markdown]
# Now click on your image in the top-right corner of the page.
#
# *   Navigate to the API section and click "Create New API Token" to download the kaggle.json file. The json file contains username and key and it should be pasted in "~/.kaggle/" folder in Google Colab to use the API.

# %% [markdown]
# ![Kaggle TOKEN PAGE.PNG](data:image/png;base64,...)

# %% [markdown]
# Sign in to colab.research.google.com using your email.
#
#
# *  Click on "New Notebook" at the bottom of the page.

# %% [markdown]
# ![Colab Homepage.PNG](data:image/png;base64,...)

# %% [markdown]
# Once you see the homepage, you can edit the file name

# %% [markdown]
# ![Colab Homepageee.PNG](data:image/png;base64,...)

# %% [markdown]
# Install kaggle

# %%
# !pip install -q kaggle

# %%
 from google.colab import files
 files.upload()
# Out:
#      <input type="file" id="files-53977804-5827-48a7-a354-84b7bf6a8f20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53977804-5827-48a7-a354-84b7bf6a8f20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vikthour","key":"854772165a20adf6b63b62f944d1936f"}'}

# %%
# Create a kaggle folder
! mkdir ~/.kaggle

# %%
# Copy the kaggle.json file into the /.kaggle folder
! cp kaggle.json ~/.kaggle/

# %%
# Permission for the json to be executed.

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# To list all available dataset in the kaggle database.

! kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              235KB  2021-09-09 20:40:01          12030
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           7332
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           2971
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-07-03 18:37:20           2873
# ...

# %% [markdown]
# # Import the dataset of your choice from Kaggle.

# %% [markdown]
# 1.   Go to the dataset page
# 2.   Find the dataset you want to work on.

# %% [markdown]
# # For competition datasets
# !kaggle competitions download -c (dataset title) -p (folder to download to)
#
# # For other datasets
# !kaggle datasets download -d (user)/(dataset title) -p (folder to download to)
#
# The dataset title is the emboldened part marked ** ** in the example below.
#
# https://www.kaggle.com/brsdincer/**vehicle-detection-image-set**
#
# The dataset user is the italicized word (marked * *) in the example below
#
# https://www.kaggle.com/*brsdincer*/vehicle-detection-image-set

# %%
! kaggle datasets download -d brsdincer/vehicle-detection-image-set -p Dataset
# Out:
# ...
#  91% 109M/119M [00:01<00:00, 104MB/s]
# 100% 119M/119M [00:01<00:00, 112MB/s]

# %%
# Now we need to unzip the downloaded files
# !unzip Dataset/vehicle-detection-image-set.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/vehicles/4414.png
#   inflating: data/vehicles/4415.png
#   inflating: data/vehicles/4416.png
#   inflating: data/vehicles/4417.png
#   inflating: data/vehicles/4418.png
#   inflating: data/vehicles/4419.png
#   inflating: data/vehicles/442.png
#   inflating: data/vehicles/4420.png
#   inflating: data/vehicles/4421.png
#   inflating: data/vehicles/4422.png
#   inflating: data/vehicles/4423.png
#   inflating: data/vehicles/4424.png
#   inflating: data/vehicles/4425.png
#   inflating: data/vehicles/4426.png
#   inflating: data/vehicles/4427.png
#   inflating: data/vehicles/4428.png
#   inflating: data/vehicles/4429.png
#   inflating: data/vehicles/443.png
#   inflating: data/vehicles/4430.png
#   inflating: data/vehicles/4431.png
#   inflating: data/vehicles/4432.png
#   inflating: data/vehicles/4433.png
#   inflating: data/vehicles/4434.png
#   inflating: data/vehicles/4435.png
# ...
